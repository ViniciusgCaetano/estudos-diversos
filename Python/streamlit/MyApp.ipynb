# %%
# %pip install streamlit
import streamlit as st
# Out:
# ...
#   Using cached blinker-1.4.tar.gz (111 kB)
# ...
#   Using cached cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# ...
#   Using cached validators-0.18.2-py3-none-any.whl (19 kB)
# ...
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# ...
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# ...
#   Using cached tzlocal-4.1-py3-none-any.whl (19 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached base58-2.1.1-py3-none-any.whl (5.6 kB)
# ...
#   Using cached GitPython-3.1.26-py3-none-any.whl (180 kB)
# ...
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# ...
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# ...
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached tzdata-2021.5-py2.py3-none-any.whl (339 kB)
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=2212ece4756f554506fb53509edb804010999dd962b30fc6e1109749fb356689
# ...

# %%
st.write("""
VAMOOO
""")
# Out:
# 2022-02-12 13:55:45.944
# ...
#   command:
#
#     streamlit run C:\Users\Vinicius12011807\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
